# %%
1
# Out:
# 1

# %%
1.0
# Out:
# 1.0

# %%
1 +1
# Out:
# 2

# %%
1 * 3
# Out:
# 3

# %%
1 / 2.0
# Out:
# 0.5

# %%
2 ** 4
# Out:
# 16

# %%
2 +3 * 5 + 5
# Out:
# 22

# %%
(2+3) *(5 + 5)
# Out:
# 50

# %%
4 % 2
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
8 % 2
# Out:
# 0
